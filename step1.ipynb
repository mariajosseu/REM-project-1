# %% [markdown]
# # Assignment 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We selected IEEE RTS 24-Bus System. Which consist of
#
# - 24 bus bars
# - 12 conventional power plants
# - 6 wind power plants
#
#
# Assumption:
#
# - Pmin for every power plant is 0
# - every wind power plant has the same installed capacity and turbine type but different locations
# - we are using the average wind forcast as the max campacity of the power plant
